# %%
#add all the tiles
# %run 'aoi_selector_ui.ipynb'
# %run 'import_alerts_ui.ipynb'
# %run 'sepal_process_ui.ipynb'
# %run 'about_ui.ipynb'

# %%
ma_aoi

# %%
ma_alert_driver

# %%
ma_sepal

# %%
ma_results

# %%
ma_about

# %%
ma_disclaimer
